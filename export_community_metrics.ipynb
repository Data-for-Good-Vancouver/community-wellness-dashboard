# %% [markdown]
# <a href="https://colab.research.google.com/github/vvnjin/community-wellness-dashboard/blob/main/export_community_metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### This notebook is for exporting all education metrics calculated in distance.ipynb and school_quality.ipynb. Data is exported to an Excel workbook in the  Community Wellness Dashboard - Dfg Google Drive.
#
# The data is formatted to fit a data model, which is read by Tableau to create the community wellness dashboard
#
#
# Author: Vivian Jin

# %% [markdown]
# ## Setup GDrive access

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os

drive_path = '/content/gdrive/MyDrive/Colab Notebooks/Source Data'
drive_contents = os.listdir(drive_path)

# Find the shared drives
shared_drives = [item for item in drive_contents]
print("Shared Drives:", shared_drives)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Shared Drives: ['01 - Geographic', '02 - Education', '03 - Population']

# %%
import pandas as pd

# %% [markdown]
# ## 1. Read in existing data, so we can append to existing versions

# %%
LATEST_EDUCATION_METRICS_FILE_NAME = '/content/gdrive/MyDrive/Colab Notebooks/Final Data/results_data_22-Nov-2023.xlsx'

output_wkbk_sheets = pd.read_excel(LATEST_EDUCATION_METRICS_FILE_NAME, sheet_name=None)

print("number of sheets: ", len(output_wkbk_sheets))

for index, sheet in enumerate(output_wkbk_sheets):
  print(sheet)
  globals()[f"{sheet}_df"] = pd.read_excel(LATEST_EDUCATION_METRICS_FILE_NAME, sheet_name=index)
# Out:
# number of sheets:  4
# releases
# regions
# indexes
# region_metrics

# %%
releases_df
# Out:
#    id      release_name release_date
# 0   0  Rel0.0_22Nov2023  22-Nov-2023

# %% [markdown]
# ## Create new release version

# %%
from datetime import datetime
# Get the current date and time
current_date = datetime.now().strftime("%d%b%Y")
current_date2 = datetime.now().strftime("%d-%b-%Y")

# SET VERSIONING
RELEASE_ID = releases_df.loc[len(releases_df) - 1, 'id'] + 1
VERSION_NUMBER = 1.0
RELEASE_NAME = f'Rel{VERSION_NUMBER}_{current_date}'
RELEASE_DATE = current_date2

new_row = {'id': RELEASE_ID, 'release_name': RELEASE_NAME, 'release_date': RELEASE_DATE}
releases_df = releases_df.append(new_row, ignore_index=True)

releases_df
# Out:
# <ipython-input-5-febb5e1f8ccb>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   releases_df = releases_df.append(new_row, ignore_index=True)
#    id      release_name release_date
# 0   0  Rel0.0_22Nov2023  22-Nov-2023
# 1   1  Rel1.0_08Dec2023  08-Dec-2023

# %%
regions_df
# Out:
#     id                region_name  region_population region_type  \
# 0    0       Vancouver-Fraserview              58686   community
# 1    1         Vancouver-Hastings              58095   community
# 2    2       Vancouver-Kensington              58593   community
# 3    3          Vancouver-Langara              55724   community
# 4    4  Vancouver-Little Mountain              57034   community
# 5    5       Vancouver-Point Grey              56818   community
# 6    6        Vancouver-Quilchena              56957   community
# 7    7          Vancouver-Renfrew              56922   community
# 8    8  Vancouver-South Granville              56134   community
# 9    9       Vancouver-Strathcona              54588   community
# 10  10         Vancouver-West End              57332   community
# 11  11         Vancouver-Yaletown              55307   community
# 12  12                  Vancouver             682190        city
#
#              notes
# 0   electoral_area
# 1   electoral_area
# 2   electoral_area
# 3   electoral_area
# 4   electoral_area
# 5   electoral_area
# 6   electoral_area
# 7   electoral_area
# 8   electoral_area
# 9   electoral_area
# 10  electoral_area
# 11  electoral_area
# 12             NaN

# %%
indexes_df
# Out:
#    id index_name
# 0   0  Education
# 1   1     Health
# 2   2    Housing

# %% [markdown]
# # Output the following metrics:
#  - median distance for each electoral area for each facility type
#  - median distance score for each electoral area
#  - mean distance score for vancouver
#  - mean capacity percentages for each electoral area
#  - mean capacity score for each electoral area (for capacity, we want outliers to impact the scoring)
#  - mean capacity score for vancouver
#  - median fraser score for each electoral area
#  - median fraser score for vancouver
#
# - overall education score for vancouver
# - overall education score for each electoral area

# %%
properties_df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/Final Data/properties_with_distances.csv')

# %%
def aggregate_and_rename(properties_df, agg_type):
    agg_columns = ['closest_library', 'closest_school', 'closest_strongstart_school', 'closest_adult_education_school', 'closest_postsecondary_school']

    results = []

    for col in agg_columns:
        name_col = f"{col}_name"
        dist_col = f"{col}_dist_km"

        if agg_type == 'max':
            agg_df = properties_df.groupby("electoral_area")[name_col].unique().agg(list).reset_index()
            dist_df = properties_df.groupby("electoral_area")[dist_col].max().reset_index()
        elif agg_type == 'mean':
            agg_df = properties_df.groupby("electoral_area")[name_col].unique().agg(list).reset_index()
            dist_df = properties_df.groupby("electoral_area")[dist_col].mean().reset_index()
        elif agg_type == 'median':
            agg_df = properties_df.groupby("electoral_area")[name_col].unique().agg(list).reset_index()
            dist_df = properties_df.groupby("electoral_area")[dist_col].median().reset_index()

        combined_df = pd.merge(agg_df, dist_df, on='electoral_area', how='outer')
        results.append(combined_df)

    cleaned_dfs = []

    for df in results:
        for col in df.columns:
            new_col_name = f"{col}_{agg_type}" if col.endswith('km') else f"{col}_agg_list" if col.endswith('name') else col
            df = df.rename(columns={col: new_col_name})

        cleaned_dfs.append(df)

    final_df = cleaned_dfs[0]

    for i in range(1, len(cleaned_dfs)):
        final_df = final_df.merge(cleaned_dfs[i], on='electoral_area')

    return final_df

# %%
headers =["release_id_fk","region_id_fk","index_id_fk","calculation_type","metric_key","metric_entity","metric_value","metric_unit"]

distances_df = pd.DataFrame(columns=headers)

# VARIABLES TO SET MANUALLY
AGGREGATE = 'median'
INDEX = 'Education'
CALCULATION_TYPE = "distance"
metric_unit = 'km'

# Get variables
release_id_fk = RELEASE_ID
metric_key = f'closest_facility_{AGGREGATE}_distance'
index_id_fk = indexes_df[indexes_df['index_name'] == INDEX]['id'][0]

# Calculate aggregate
median_result = aggregate_and_rename(properties_df, AGGREGATE)

# Melt aggregate df
value_cols = []
id_cols = []
for col in median_result.columns:
  if "km" in col:
    value_cols.append(col)
  elif 'area' in col:
    id_cols.append(col)

melted_df = pd.melt(median_result, id_vars=id_cols, value_vars=value_cols)

for index, row in melted_df.iterrows():
  region_id_fk = regions_df[regions_df['region_name'] == row['electoral_area']]['id']
  metric_entity = row['variable'].split('_')[1]
  metric_value = row['value']

  new_row = {"release_id_fk":release_id_fk, "region_id_fk": region_id_fk, "index_id_fk": index_id_fk, "calculation_type": CALCULATION_TYPE, "metric_key": metric_key, "metric_entity": metric_entity, "metric_value": metric_value, "metric_unit": metric_unit}

  distances_df = pd.concat([distances_df, pd.DataFrame(new_row)], ignore_index=True)

distances_df.sort_values(by='region_id_fk')
# Out:
#    release_id_fk region_id_fk index_id_fk calculation_type  \
# 0              1            0           0         distance
# 24             1            0           0         distance
# 36             1            0           0         distance
# 12             1            0           0         distance
# 48             1            0           0         distance
# 37             1            1           0         distance
# 25             1            1           0         distance
# 49             1            1           0         distance
# 13             1            1           0         distance
# 1              1            1           0         distance
# 26             1            2           0         distance
# 2              1            2           0         distance
# 14             1            2           0         distance
# 38             1            2           0         distance
# 50             1            2           0         distance
# 27             1            3           0         distance
# 3              1            3           0         distance
# 39             1            3           0         distance
# 51             1            3           0         distance
# 15             1            3           0         distance
# 4              1            4           0         distance
# 28             1            4           0         distance
# 52             1            4           0         distance
# 16             1            4           0         distance
# 40             1            4           0         distance
# 53             1            5           0         distance
# 41             1            5           0         distance
# 29             1            5           0         distance
# 5              1            5           0         distance
# 17             1            5           0         distance
# 30             1            6           0         distance
# 6              1            6           0         distance
# 42             1            6           0         distance
# 54             1            6           0         distance
# 18             1            6           0         distance
# 43             1            7           0         distance
# 7              1            7           0         distance
# 19             1            7           0         distance
# 55             1            7           0         distance
# 31             1            7           0         distance
# 8              1            8           0         distance
# 56             1            8           0         distance
# 32             1            8           0         distance
# 44             1            8           0         distance
# 20             1            8           0         distance
# 21             1            9           0         distance
# 33             1            9           0         distance
# 45             1            9           0         distance
# 57             1            9           0         distance
# 9              1            9           0         distance
# 22             1           10           0         distance
# 46             1           10           0         distance
# 34             1           10           0         distance
# 58             1           10           0         distance
# 10             1           10           0         distance
# 47             1           11           0         distance
# 23             1           11           0         distance
# 11             1           11           0         distance
# 35             1           11           0         distance
# 59             1           11           0         distance
#
#                           metric_key  metric_entity  metric_value metric_unit
# 0   closest_facility_median_distance        library      0.795365          km
# 24  closest_facility_median_distance    strongstart      0.611747          km
# 36  closest_facility_median_distance          adult      2.724741          km
# 12  closest_facility_median_distance         school      0.351449          km
# 48  closest_facility_median_distance  postsecondary      3.517937          km
# 37  closest_facility_median_distance          adult      2.794882          km
# 25  closest_facility_median_distance    strongstart      1.052886          km
# 49  closest_facility_median_distance  postsecondary      1.599343          km
# 13  closest_facility_median_distance         school      0.299177          km
# 1   closest_facility_median_distance        library      1.136348          km
# 26  closest_facility_median_distance    strongstart      0.878359          km
# 2   closest_facility_median_distance        library      0.933617          km
# 14  closest_facility_median_distance         school      0.347274          km
# 38  closest_facility_median_distance          adult      1.549608          km
# 50  closest_facility_median_distance  postsecondary      2.332058          km
# 27  closest_facility_median_distance    strongstart      2.161016          km
# 3   closest_facility_median_distance        library      1.193681          km
# 39  closest_facility_median_distance          adult      1.661761          km
# 51  closest_facility_median_distance  postsecondary      1.757047          km
# 15  closest_facility_median_distance         school      0.357761          km
# 4   closest_facility_median_distance        library      0.869728          km
# 28  closest_facility_median_distance    strongstart      1.411584          km
# 52  closest_facility_median_distance  postsecondary      1.392888          km
# 16  closest_facility_median_distance         school      0.344793          km
# 40  closest_facility_median_distance          adult      1.548315          km
# 53  closest_facility_median_distance  postsecondary      3.344128          km
# 41  closest_facility_median_distance          adult      6.821567          km
# 29  closest_facility_median_distance    strongstart      6.751826          km
# 5   closest_facility_median_distance        library      0.756364          km
# 17  closest_facility_median_distance         school      0.406907          km
# 30  closest_facility_median_distance    strongstart      5.437390          km
# 6   closest_facility_median_distance        library      1.065478          km
# 42  closest_facility_median_distance          adult      4.788845          km
# 54  closest_facility_median_distance  postsecondary      4.054910          km
# 18  closest_facility_median_distance         school      0.442326          km
# 43  closest_facility_median_distance          adult      3.504494          km
# 7   closest_facility_median_distance        library      0.837615          km
# 19  closest_facility_median_distance         school      0.317870          km
# 55  closest_facility_median_distance  postsecondary      1.742237          km
# 31  closest_facility_median_distance    strongstart      0.670315          km
# 8   closest_facility_median_distance        library      0.976122          km
# 56  closest_facility_median_distance  postsecondary      1.683276          km
# 32  closest_facility_median_distance    strongstart      4.024163          km
# 44  closest_facility_median_distance          adult      4.367663          km
# 20  closest_facility_median_distance         school      0.312719          km
# 21  closest_facility_median_distance         school      0.288063          km
# 33  closest_facility_median_distance    strongstart      0.498807          km
# 45  closest_facility_median_distance          adult      0.850028          km
# 57  closest_facility_median_distance  postsecondary      0.788325          km
# 9   closest_facility_median_distance        library      0.733059          km
# 22  closest_facility_median_distance         school      0.310153          km
# 46  closest_facility_median_distance          adult      4.078333          km
# 34  closest_facility_median_distance    strongstart      3.782669          km
# 58  closest_facility_median_distance  postsecondary      1.008937          km
# 10  closest_facility_median_distance        library      0.620063          km
# 47  closest_facility_median_distance          adult      2.041873          km
# 23  closest_facility_median_distance         school      0.578077          km
# 11  closest_facility_median_distance        library      0.832658          km
# 35  closest_facility_median_distance    strongstart      1.730800          km
# 59  closest_facility_median_distance  postsecondary      0.610736          km

# %%
distance_scores_file = "/content/gdrive/MyDrive/Colab Notebooks/Final Data/electoral_area_with_distance_scores.csv"
distance_scores_file_df = pd.read_csv(distance_scores_file)
distance_scores_file_df
# Out:
#     Unnamed: 0             electoral_area             metric_key  \
# 0            0       Vancouver-Fraserview  median_distance_score
# 1            1         Vancouver-Hastings  median_distance_score
# 2            2       Vancouver-Kensington  median_distance_score
# 3            3          Vancouver-Langara  median_distance_score
# 4            4  Vancouver-Little Mountain  median_distance_score
# 5            5       Vancouver-Point Grey  median_distance_score
# 6            6        Vancouver-Quilchena  median_distance_score
# 7            7          Vancouver-Renfrew  median_distance_score
# 8            8  Vancouver-South Granville  median_distance_score
# 9            9       Vancouver-Strathcona  median_distance_score
# 10          10         Vancouver-West End  median_distance_score
# 11          11         Vancouver-Yaletown  median_distance_score
# 12          12                  Vancouver   total_distance_score
#
#     distance_score
# 0         7.951367
# 1         7.999958
# 2         8.251642
# 3         7.877873
# 4         8.373820
# 5         6.653261
# 6         6.660691
# 7         8.119015
# 8         7.288850
# 9         9.039126
# 10        7.721810
# 11        8.387029
# 12        7.860370

# %%
distance_scores_df = pd.DataFrame()
for index, row in distance_scores_file_df.iterrows():
  region_id_fk = regions_df[regions_df['region_name'] == row['electoral_area']]['id']
  metric_entity = "all_education_facilities"
  metric_value = row['distance_score']
  if row['electoral_area'] == 'Vancouver':
    metric_key = 'city_mean_distance_score'

  else:
    metric_key = 'median_distance_score'
  metric_unit = "pts"

  new_row = {"release_id_fk":release_id_fk, "region_id_fk": region_id_fk, "index_id_fk": index_id_fk, "calculation_type": CALCULATION_TYPE, "metric_key": metric_key, "metric_entity": metric_entity, "metric_value": metric_value, "metric_unit": metric_unit}
  distance_scores_df = pd.concat([distance_scores_df, pd.DataFrame(new_row)], axis=0)

distance_scores_df
# Out:
#     release_id_fk  region_id_fk  index_id_fk calculation_type  \
# 0               1             0            0         distance
# 1               1             1            0         distance
# 2               1             2            0         distance
# 3               1             3            0         distance
# 4               1             4            0         distance
# 5               1             5            0         distance
# 6               1             6            0         distance
# 7               1             7            0         distance
# 8               1             8            0         distance
# 9               1             9            0         distance
# 10              1            10            0         distance
# 11              1            11            0         distance
# 12              1            12            0         distance
#
#                   metric_key             metric_entity  metric_value  \
# 0      median_distance_score  all_education_facilities      7.951367
# 1      median_distance_score  all_education_facilities      7.999958
# 2      median_distance_score  all_education_facilities      8.251642
# 3      median_distance_score  all_education_facilities      7.877873
# 4      median_distance_score  all_education_facilities      8.373820
# 5      median_distance_score  all_education_facilities      6.653261
# 6      median_distance_score  all_education_facilities      6.660691
# 7      median_distance_score  all_education_facilities      8.119015
# 8      median_distance_score  all_education_facilities      7.288850
# 9      median_distance_score  all_education_facilities      9.039126
# 10     median_distance_score  all_education_facilities      7.721810
# 11     median_distance_score  all_education_facilities      8.387029
# 12  city_mean_distance_score  all_education_facilities      7.860370
#
#    metric_unit
# 0          pts
# 1          pts
# 2          pts
# 3          pts
# 4          pts
# 5          pts
# 6          pts
# 7          pts
# 8          pts
# 9          pts
# 10         pts
# 11         pts
# 12         pts

# %% [markdown]
# ## Merge distances and distance scores dfs

# %%
merged_distance_scores_df = pd.concat([distances_df, distance_scores_df], ignore_index=True)
merged_distance_scores_df.head()
# Out:
#   release_id_fk region_id_fk index_id_fk calculation_type  \
# 0             1            0           0         distance
# 1             1            1           0         distance
# 2             1            2           0         distance
# 3             1            3           0         distance
# 4             1            4           0         distance
#
#                          metric_key metric_entity  metric_value metric_unit
# 0  closest_facility_median_distance       library      0.795365          km
# 1  closest_facility_median_distance       library      1.136348          km
# 2  closest_facility_median_distance       library      0.933617          km
# 3  closest_facility_median_distance       library      1.193681          km
# 4  closest_facility_median_distance       library      0.869728          km

# %% [markdown]
# ## Calculate mean capacity percentages per electoral area and for Vancouver

# %%
school_qualities_file = "/content/gdrive/MyDrive/Colab Notebooks/Intermediate Data/02 - Education/school_quality_fraser_and_capacity_scores.csv"
school_qualities_df = pd.read_csv(school_qualities_file)

mean_capacity_df = pd.DataFrame(school_qualities_df.groupby('electoral_area')['school_capacity_%'].mean().reset_index())
mean_capacity_df = mean_capacity_df.rename(columns={'school_capacity_%':'metric_value'})
mean_capacity_df['metric_key'] = 'mean_capacity_%'
mean_capacity_df['metric_unit'] = 'percentage'

total_capacity_score = mean_capacity_df['metric_value'].mean()

vancouver_row = "Vancouver", total_capacity_score,'city_mean_capacity_%' , 'percentage'
mean_capacity_df.loc[len(mean_capacity_df)] = vancouver_row

mean_capacity_df
# Out:
#                electoral_area  metric_value            metric_key metric_unit
# 0        Vancouver-Fraserview     84.923077       mean_capacity_%  percentage
# 1          Vancouver-Hastings     83.069326       mean_capacity_%  percentage
# 2        Vancouver-Kensington     75.909091       mean_capacity_%  percentage
# 3           Vancouver-Langara     94.736364       mean_capacity_%  percentage
# 4   Vancouver-Little Mountain    103.357143       mean_capacity_%  percentage
# 5        Vancouver-Point Grey     95.051956       mean_capacity_%  percentage
# 6         Vancouver-Quilchena     94.738889       mean_capacity_%  percentage
# 7           Vancouver-Renfrew     86.938836       mean_capacity_%  percentage
# 8   Vancouver-South Granville    105.368127       mean_capacity_%  percentage
# 9        Vancouver-Strathcona     83.694215       mean_capacity_%  percentage
# 10         Vancouver-West End    127.666667       mean_capacity_%  percentage
# 11         Vancouver-Yaletown    106.500000       mean_capacity_%  percentage
# 12                  Vancouver     95.162807  city_mean_capacity_%  percentage

# %%
quality_scores_df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Final Data/electoral_area_with_fraser_and_capacity_scores.csv")

# Calculate Vancouver totals
total_fraser_score = quality_scores_df['median_Fraser_score'].mean()
total_capacity_score = quality_scores_df['mean_capacity_score'].mean()

quality_scores_df = quality_scores_df.melt('electoral_area').rename(columns={'variable':'metric_key', 'value':'metric_value'})
quality_scores_df

vancouver_fraser_score_row = 'Vancouver', 'city_mean_Fraser_score', total_fraser_score
quality_scores_df.loc[len(quality_scores_df)] = vancouver_fraser_score_row

vancouver_capacity_score_row = 'Vancouver', 'city_mean_capacity_score', total_capacity_score
quality_scores_df.loc[len(quality_scores_df)] = vancouver_capacity_score_row

quality_scores_df['metric_unit'] = 'pts'
quality_scores_df
# Out:
#                electoral_area                metric_key  metric_value  \
# 0        Vancouver-Fraserview       median_Fraser_score      6.600000
# 1          Vancouver-Hastings       median_Fraser_score      6.600000
# 2        Vancouver-Kensington       median_Fraser_score      5.350000
# 3           Vancouver-Langara       median_Fraser_score      6.400000
# 4   Vancouver-Little Mountain       median_Fraser_score      7.350000
# 5        Vancouver-Point Grey       median_Fraser_score      7.700000
# 6         Vancouver-Quilchena       median_Fraser_score      7.300000
# 7           Vancouver-Renfrew       median_Fraser_score      8.250000
# 8   Vancouver-South Granville       median_Fraser_score      7.600000
# 9        Vancouver-Strathcona       median_Fraser_score      6.500000
# 10         Vancouver-West End       median_Fraser_score      4.750000
# 11         Vancouver-Yaletown       median_Fraser_score      6.250000
# 12       Vancouver-Fraserview       mean_capacity_score      8.604311
# 13         Vancouver-Hastings       mean_capacity_score      8.401586
# 14       Vancouver-Kensington       mean_capacity_score      8.026090
# 15          Vancouver-Langara       mean_capacity_score      9.024876
# 16  Vancouver-Little Mountain       mean_capacity_score      7.958397
# 17       Vancouver-Point Grey       mean_capacity_score      9.140299
# 18        Vancouver-Quilchena       mean_capacity_score      8.506650
# 19          Vancouver-Renfrew       mean_capacity_score      8.621786
# 20  Vancouver-South Granville       mean_capacity_score      8.316565
# 21       Vancouver-Strathcona       mean_capacity_score      7.552169
# 22         Vancouver-West End       mean_capacity_score      6.091999
# 23         Vancouver-Yaletown       mean_capacity_score      9.390477
# 24                  Vancouver    city_mean_Fraser_score      6.720833
# 25                  Vancouver  city_mean_capacity_score      8.302934
#
#    metric_unit
# 0          pts
# 1          pts
# 2          pts
# 3          pts
# 4          pts
# 5          pts
# 6          pts
# 7          pts
# 8          pts
# 9          pts
# 10         pts
# 11         pts
# 12         pts
# 13         pts
# 14         pts
# 15         pts
# 16         pts
# 17         pts
# 18         pts
# 19         pts
# 20         pts
# 21         pts
# 22         pts
# 23         pts
# 24         pts
# 25         pts

# %% [markdown]
# ## Merge capacity_% and mean_capacity_%, and median_Fraser_score dfs

# %%
merged_quality_scores_df = pd.concat([quality_scores_df, mean_capacity_df], ignore_index=True)
merged_quality_scores_df.head()
# Out:
#               electoral_area           metric_key  metric_value metric_unit
# 0       Vancouver-Fraserview  median_Fraser_score          6.60         pts
# 1         Vancouver-Hastings  median_Fraser_score          6.60         pts
# 2       Vancouver-Kensington  median_Fraser_score          5.35         pts
# 3          Vancouver-Langara  median_Fraser_score          6.40         pts
# 4  Vancouver-Little Mountain  median_Fraser_score          7.35         pts

# %%
merged_quality_scores_df
CALCULATION_TYPE = 'quality'

complete_quality_scores_df = pd.DataFrame()
for index, row in merged_quality_scores_df.iterrows():
  region_id_fk = regions_df[regions_df['region_name'] == row['electoral_area']]['id']
  metric_entity = 'schools'
  metric_key = row['metric_key']
  metric_value = row['metric_value']
  metric_unit = row['metric_unit']

  new_row = {"release_id_fk":release_id_fk, "region_id_fk": region_id_fk, "index_id_fk": index_id_fk, "calculation_type": CALCULATION_TYPE, "metric_key": metric_key, "metric_entity": metric_entity, "metric_value": metric_value, "metric_unit": metric_unit}
  complete_quality_scores_df = pd.concat([complete_quality_scores_df, pd.DataFrame(new_row)], axis=0)

complete_quality_scores_df
# Out:
#     release_id_fk  region_id_fk  index_id_fk calculation_type  \
# 0               1             0            0          quality
# 1               1             1            0          quality
# 2               1             2            0          quality
# 3               1             3            0          quality
# 4               1             4            0          quality
# 5               1             5            0          quality
# 6               1             6            0          quality
# 7               1             7            0          quality
# 8               1             8            0          quality
# 9               1             9            0          quality
# 10              1            10            0          quality
# 11              1            11            0          quality
# 0               1             0            0          quality
# 1               1             1            0          quality
# 2               1             2            0          quality
# 3               1             3            0          quality
# 4               1             4            0          quality
# 5               1             5            0          quality
# 6               1             6            0          quality
# 7               1             7            0          quality
# 8               1             8            0          quality
# 9               1             9            0          quality
# 10              1            10            0          quality
# 11              1            11            0          quality
# 12              1            12            0          quality
# 12              1            12            0          quality
# 0               1             0            0          quality
# 1               1             1            0          quality
# 2               1             2            0          quality
# 3               1             3            0          quality
# 4               1             4            0          quality
# 5               1             5            0          quality
# 6               1             6            0          quality
# 7               1             7            0          quality
# 8               1             8            0          quality
# 9               1             9            0          quality
# 10              1            10            0          quality
# 11              1            11            0          quality
# 12              1            12            0          quality
#
#                   metric_key metric_entity  metric_value metric_unit
# 0        median_Fraser_score       schools      6.600000         pts
# 1        median_Fraser_score       schools      6.600000         pts
# 2        median_Fraser_score       schools      5.350000         pts
# 3        median_Fraser_score       schools      6.400000         pts
# 4        median_Fraser_score       schools      7.350000         pts
# 5        median_Fraser_score       schools      7.700000         pts
# 6        median_Fraser_score       schools      7.300000         pts
# 7        median_Fraser_score       schools      8.250000         pts
# 8        median_Fraser_score       schools      7.600000         pts
# 9        median_Fraser_score       schools      6.500000         pts
# 10       median_Fraser_score       schools      4.750000         pts
# 11       median_Fraser_score       schools      6.250000         pts
# 0        mean_capacity_score       schools      8.604311         pts
# 1        mean_capacity_score       schools      8.401586         pts
# 2        mean_capacity_score       schools      8.026090         pts
# 3        mean_capacity_score       schools      9.024876         pts
# 4        mean_capacity_score       schools      7.958397         pts
# 5        mean_capacity_score       schools      9.140299         pts
# 6        mean_capacity_score       schools      8.506650         pts
# 7        mean_capacity_score       schools      8.621786         pts
# 8        mean_capacity_score       schools      8.316565         pts
# 9        mean_capacity_score       schools      7.552169         pts
# 10       mean_capacity_score       schools      6.091999         pts
# 11       mean_capacity_score       schools      9.390477         pts
# 12    city_mean_Fraser_score       schools      6.720833         pts
# 12  city_mean_capacity_score       schools      8.302934         pts
# 0            mean_capacity_%       schools     84.923077  percentage
# 1            mean_capacity_%       schools     83.069326  percentage
# 2            mean_capacity_%       schools     75.909091  percentage
# 3            mean_capacity_%       schools     94.736364  percentage
# 4            mean_capacity_%       schools    103.357143  percentage
# 5            mean_capacity_%       schools     95.051956  percentage
# 6            mean_capacity_%       schools     94.738889  percentage
# 7            mean_capacity_%       schools     86.938836  percentage
# 8            mean_capacity_%       schools    105.368127  percentage
# 9            mean_capacity_%       schools     83.694215  percentage
# 10           mean_capacity_%       schools    127.666667  percentage
# 11           mean_capacity_%       schools    106.500000  percentage
# 12      city_mean_capacity_%       schools     95.162807  percentage

# %% [markdown]
# ## Merge all school distance and quality metrics

# %%
scores_df = pd.concat([complete_quality_scores_df, merged_distance_scores_df], ignore_index =True)
scores_df.sort_values(by=['region_id_fk', 'metric_key'])
# Out:
#     release_id_fk region_id_fk index_id_fk calculation_type  \
# 39              1            0           0         distance
# 51              1            0           0         distance
# 63              1            0           0         distance
# 75              1            0           0         distance
# 87              1            0           0         distance
# ..            ...          ...         ...              ...
# 110             1           11           0         distance
# 24              1           12           0          quality
# 38              1           12           0          quality
# 25              1           12           0          quality
# 111             1           12           0         distance
#
#                            metric_key             metric_entity  metric_value  \
# 39   closest_facility_median_distance                   library      0.795365
# 51   closest_facility_median_distance                    school      0.351449
# 63   closest_facility_median_distance               strongstart      0.611747
# 75   closest_facility_median_distance                     adult      2.724741
# 87   closest_facility_median_distance             postsecondary      3.517937
# ..                                ...                       ...           ...
# 110             median_distance_score  all_education_facilities      8.387029
# 24             city_mean_Fraser_score                   schools      6.720833
# 38               city_mean_capacity_%                   schools     95.162807
# 25           city_mean_capacity_score                   schools      8.302934
# 111          city_mean_distance_score  all_education_facilities      7.860370
#
#     metric_unit
# 39           km
# 51           km
# 63           km
# 75           km
# 87           km
# ..          ...
# 110         pts
# 24          pts
# 38   percentage
# 25          pts
# 111         pts
#
# [112 rows x 8 columns]

# %%
electoral_area_education_scores
# Out:
#     region_id_fk  metric_value
# 0              0      7.718559
# 1              1      7.667181
# 2              2      7.209244
# 3              3      7.767583
# 4              4      7.894073
# 5              5      7.831187
# 6              6      7.489114
# 7              7      8.330267
# 8              8      7.735138
# 9              9      7.697098
# 10            10      6.187936
# 11            11      8.009169

# %% [markdown]
# ## Calculate overall Vancouver education score, and overall education scores for each electoral area

# %%
all_scores_df = scores_df

electoral_area_education_scores = all_scores_df[(~all_scores_df['metric_key'].str.startswith('city')) & (all_scores_df['metric_unit'] == 'pts')]
electoral_area_education_scores = pd.DataFrame(electoral_area_education_scores.groupby("region_id_fk")['metric_value'].mean().reset_index())

for index, row in electoral_area_education_scores.iterrows():
    new_row = {"release_id_fk":release_id_fk, "region_id_fk": int(row['region_id_fk']), "index_id_fk": index_id_fk, "calculation_type": 'overall_education', "metric_key": 'overall_education_score', "metric_entity": 'distance_and_school_quality', "metric_value": row['metric_value'], "metric_unit": 'pts'}
    all_scores_df = all_scores_df.append(new_row, ignore_index=True)

vancouver_id_fk = int(regions_df[regions_df['region_name'] == 'Vancouver']['id'])
vancouver_education_score = scores_df[(scores_df['metric_key'].str.startswith('city')) & (all_scores_df['metric_unit'] == 'pts')]['metric_value'].mean()
vancouver_row = {"release_id_fk":release_id_fk, "region_id_fk": vancouver_id_fk, "index_id_fk": index_id_fk, "calculation_type": 'overall_education', "metric_key": 'city_overall_education_score', "metric_entity": 'distance_and_school_quality', "metric_value": vancouver_education_score, "metric_unit": 'pts'}
all_scores_df = all_scores_df.append(vancouver_row, ignore_index=True)

all_scores_df
# Out:
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(new_row, ignore_index=True)
# <ipython-input-70-e0051d56db48>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   vancouver_education_score = scores_df[(scores_df['metric_key'].str.startswith('city')) & (all_scores_df['metric_unit'] == 'pts')]['metric_value'].mean()
# <ipython-input-70-e0051d56db48>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_scores_df = all_scores_df.append(vancouver_row, ignore_index=True)
#     release_id_fk region_id_fk index_id_fk   calculation_type  \
# 0               1            0           0            quality
# 1               1            1           0            quality
# 2               1            2           0            quality
# 3               1            3           0            quality
# 4               1            4           0            quality
# ..            ...          ...         ...                ...
# 120             1            8           0  overall_education
# 121             1            9           0  overall_education
# 122             1           10           0  overall_education
# 123             1           11           0  overall_education
# 124             1           12           0  overall_education
#
#                        metric_key                metric_entity  metric_value  \
# 0             median_Fraser_score                      schools      6.600000
# 1             median_Fraser_score                      schools      6.600000
# 2             median_Fraser_score                      schools      5.350000
# 3             median_Fraser_score                      schools      6.400000
# 4             median_Fraser_score                      schools      7.350000
# ..                            ...                          ...           ...
# 120       overall_education_score  distance_and_school_quality      7.735138
# 121       overall_education_score  distance_and_school_quality      7.697098
# 122       overall_education_score  distance_and_school_quality      6.187936
# 123       overall_education_score  distance_and_school_quality      8.009169
# 124  city_overall_education_score  distance_and_school_quality      7.628046
#
#     metric_unit
# 0           pts
# 1           pts
# 2           pts
# 3           pts
# 4           pts
# ..          ...
# 120         pts
# 121         pts
# 122         pts
# 123         pts
# 124         pts
#
# [125 rows x 8 columns]

# %% [markdown]
# ## Output to Excel workbook

# %%
current_date = datetime.now().strftime("%d-%b-%Y")

output_file_name = f'/content/gdrive/MyDrive/Colab Notebooks/Final Data/education_metrics_{current_date}.xlsx'

with pd.ExcelWriter(output_file_name) as writer:
    # Write each dataframe to a different sheet
    releases_df.to_excel(writer, sheet_name='releases', index=False)
    regions_df.to_excel(writer, sheet_name='regions', index=False)
    indexes_df.to_excel(writer, sheet_name='indexes', index=False)
    all_scores_df.to_excel(writer, sheet_name='region_metrics', index=False)
